# %%
import pandas as pd
import numpy as np 
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import GaussianNB 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('PSL-2016-2022.csv')
df.tail()
# Out:
#        psl_year  match_number            team_1          team_2  inning  over  \
# 50257      2022            34  Lahore Qalandars  Multan Sultans       2    19
# 50258      2022            34  Lahore Qalandars  Multan Sultans       2    19
# 50259      2022            34  Lahore Qalandars  Multan Sultans       2    20
# 50260      2022            34  Lahore Qalandars  Multan Sultans       2    20
# 50261      2022            34  Lahore Qalandars  Multan Sultans       2    20
#
#        ball  runs  wicket  total_runs  wickets  is_four  is_six  is_wicket  \
# 50257     5     0     2.0         138        9    False   False       True
# 50258     6     0     NaN         138        9    False   False      False
# 50259     1     0     NaN         138        9    False   False      False
# 50260     2     0     NaN         138        9    False   False      False
# 50261     3     0     1.0         138       10    False   False       True
#
#       wicket_text     result
# 50257      bowled  Qalandars
# 50258         NaN  Qalandars
# 50259         NaN  Qalandars
# 50260         NaN  Qalandars
# 50261      caught  Qalandars

# %%
def is_winner(row):
    if type(row['result']) == str:
        if row['result'] in row['team_2']:
            return 1
        return 0
    else:
        return 0

# %%
def is_out(row):
    if type(row['player_dismissed']) == str:
        return 1
    else:
        return 0

# %%
first_inning = df[df['inning']==1]
second_inning = df[df['inning']==2]

# %%
total_sum = first_inning.groupby(["psl_year","match_number"]).agg(
   target= ("runs","sum")
)

# %%
total_sum = total_sum.reset_index()
total_sum
# Out:
#      psl_year  match_number  target
# 0        2016             1     128
# 1        2016             2     125
# 2        2016             3     145
# 3        2016             4     147
# 4        2016             5     117
# ..        ...           ...     ...
# 210      2022            30     158
# 211      2022            31     163
# 212      2022            32     169
# 213      2022            33     168
# 214      2022            34     180
#
# [215 rows x 3 columns]

# %%
new_df = pd.merge(total_sum, second_inning,  how='left', left_on=['psl_year','match_number'], right_on = ['psl_year','match_number'])
new_df
# Out:
#        psl_year  match_number  target            team_1             team_2  \
# 0          2016             1     128  Islamabad United  Quetta Gladiators
# 1          2016             1     128  Islamabad United  Quetta Gladiators
# 2          2016             1     128  Islamabad United  Quetta Gladiators
# 3          2016             1     128  Islamabad United  Quetta Gladiators
# 4          2016             1     128  Islamabad United  Quetta Gladiators
# ...         ...           ...     ...               ...                ...
# 24181      2022            34     180  Lahore Qalandars     Multan Sultans
# 24182      2022            34     180  Lahore Qalandars     Multan Sultans
# 24183      2022            34     180  Lahore Qalandars     Multan Sultans
# 24184      2022            34     180  Lahore Qalandars     Multan Sultans
# 24185      2022            34     180  Lahore Qalandars     Multan Sultans
#
#        inning  over  ball  runs  wicket  total_runs  wickets is_four is_six  \
# 0         2.0   1.0   1.0   0.0     NaN         0.0      0.0   False  False
# 1         2.0   1.0   2.0   0.0     NaN         0.0      0.0   False  False
# 2         2.0   1.0   3.0   0.0     NaN         0.0      0.0   False  False
# 3         2.0   1.0   4.0   2.0     NaN         2.0      0.0   False  False
# 4         2.0   1.0   5.0   0.0     NaN         2.0      0.0   False  False
# ...       ...   ...   ...   ...     ...         ...      ...     ...    ...
# 24181     2.0  19.0   5.0   0.0     2.0       138.0      9.0   False  False
# 24182     2.0  19.0   6.0   0.0     NaN       138.0      9.0   False  False
# 24183     2.0  20.0   1.0   0.0     NaN       138.0      9.0   False  False
# 24184     2.0  20.0   2.0   0.0     NaN       138.0      9.0   False  False
# 24185     2.0  20.0   3.0   0.0     1.0       138.0     10.0   False  False
#
#       is_wicket wicket_text      result
# 0         False         NaN  Gladiators
# 1         False         NaN  Gladiators
# 2         False         NaN  Gladiators
# 3         False         NaN  Gladiators
# 4         False         NaN  Gladiators
# ...         ...         ...         ...
# 24181      True      bowled   Qalandars
# 24182     False         NaN   Qalandars
# 24183     False         NaN   Qalandars
# 24184     False         NaN   Qalandars
# 24185      True      caught   Qalandars
#
# [24186 rows x 17 columns]

# %%
new_df['won'] = new_df.apply(is_winner, axis=1)
new_df
# Out:
#        psl_year  match_number  target            team_1             team_2  \
# 0          2016             1     128  Islamabad United  Quetta Gladiators
# 1          2016             1     128  Islamabad United  Quetta Gladiators
# 2          2016             1     128  Islamabad United  Quetta Gladiators
# 3          2016             1     128  Islamabad United  Quetta Gladiators
# 4          2016             1     128  Islamabad United  Quetta Gladiators
# ...         ...           ...     ...               ...                ...
# 24181      2022            34     180  Lahore Qalandars     Multan Sultans
# 24182      2022            34     180  Lahore Qalandars     Multan Sultans
# 24183      2022            34     180  Lahore Qalandars     Multan Sultans
# 24184      2022            34     180  Lahore Qalandars     Multan Sultans
# 24185      2022            34     180  Lahore Qalandars     Multan Sultans
#
#        inning  over  ball  runs  wicket  total_runs  wickets is_four is_six  \
# 0         2.0   1.0   1.0   0.0     NaN         0.0      0.0   False  False
# 1         2.0   1.0   2.0   0.0     NaN         0.0      0.0   False  False
# 2         2.0   1.0   3.0   0.0     NaN         0.0      0.0   False  False
# 3         2.0   1.0   4.0   2.0     NaN         2.0      0.0   False  False
# 4         2.0   1.0   5.0   0.0     NaN         2.0      0.0   False  False
# ...       ...   ...   ...   ...     ...         ...      ...     ...    ...
# 24181     2.0  19.0   5.0   0.0     2.0       138.0      9.0   False  False
# 24182     2.0  19.0   6.0   0.0     NaN       138.0      9.0   False  False
# 24183     2.0  20.0   1.0   0.0     NaN       138.0      9.0   False  False
# 24184     2.0  20.0   2.0   0.0     NaN       138.0      9.0   False  False
# 24185     2.0  20.0   3.0   0.0     1.0       138.0     10.0   False  False
#
#       is_wicket wicket_text      result  won
# 0         False         NaN  Gladiators    1
# 1         False         NaN  Gladiators    1
# 2         False         NaN  Gladiators    1
# 3         False         NaN  Gladiators    1
# 4         False         NaN  Gladiators    1
# ...         ...         ...         ...  ...
# 24181      True      bowled   Qalandars    0
# 24182     False         NaN   Qalandars    0
# 24183     False         NaN   Qalandars    0
# 24184     False         NaN   Qalandars    0
# 24185      True      caught   Qalandars    0
#
# [24186 rows x 18 columns]

# %%
new_df['balls_left'] = 120-(((new_df['over']-1)*6)+new_df['ball'])
new_df
# Out:
#        psl_year  match_number  target            team_1             team_2  \
# 0          2016             1     128  Islamabad United  Quetta Gladiators
# 1          2016             1     128  Islamabad United  Quetta Gladiators
# 2          2016             1     128  Islamabad United  Quetta Gladiators
# 3          2016             1     128  Islamabad United  Quetta Gladiators
# 4          2016             1     128  Islamabad United  Quetta Gladiators
# ...         ...           ...     ...               ...                ...
# 24181      2022            34     180  Lahore Qalandars     Multan Sultans
# 24182      2022            34     180  Lahore Qalandars     Multan Sultans
# 24183      2022            34     180  Lahore Qalandars     Multan Sultans
# 24184      2022            34     180  Lahore Qalandars     Multan Sultans
# 24185      2022            34     180  Lahore Qalandars     Multan Sultans
#
#        inning  over  ball  runs  wicket  total_runs  wickets is_four is_six  \
# 0         2.0   1.0   1.0   0.0     NaN         0.0      0.0   False  False
# 1         2.0   1.0   2.0   0.0     NaN         0.0      0.0   False  False
# 2         2.0   1.0   3.0   0.0     NaN         0.0      0.0   False  False
# 3         2.0   1.0   4.0   2.0     NaN         2.0      0.0   False  False
# 4         2.0   1.0   5.0   0.0     NaN         2.0      0.0   False  False
# ...       ...   ...   ...   ...     ...         ...      ...     ...    ...
# 24181     2.0  19.0   5.0   0.0     2.0       138.0      9.0   False  False
# 24182     2.0  19.0   6.0   0.0     NaN       138.0      9.0   False  False
# 24183     2.0  20.0   1.0   0.0     NaN       138.0      9.0   False  False
# 24184     2.0  20.0   2.0   0.0     NaN       138.0      9.0   False  False
# 24185     2.0  20.0   3.0   0.0     1.0       138.0     10.0   False  False
#
#       is_wicket wicket_text      result  won  balls_left
# 0         False         NaN  Gladiators    1       119.0
# 1         False         NaN  Gladiators    1       118.0
# 2         False         NaN  Gladiators    1       117.0
# 3         False         NaN  Gladiators    1       116.0
# 4         False         NaN  Gladiators    1       115.0
# ...         ...         ...         ...  ...         ...
# 24181      True      bowled   Qalandars    0         7.0
# 24182     False         NaN   Qalandars    0         6.0
# 24183     False         NaN   Qalandars    0         5.0
# 24184     False         NaN   Qalandars    0         4.0
# 24185      True      caught   Qalandars    0         3.0
#
# [24186 rows x 19 columns]

# %%
# Creating the Final Dataset
final_df = new_df[['over','ball','total_runs','wickets','target','balls_left','won']]
final_df
# Out:
#        over  ball  total_runs  wickets  target  balls_left  won
# 0       1.0   1.0         0.0      0.0     128       119.0    1
# 1       1.0   2.0         0.0      0.0     128       118.0    1
# 2       1.0   3.0         0.0      0.0     128       117.0    1
# 3       1.0   4.0         2.0      0.0     128       116.0    1
# 4       1.0   5.0         2.0      0.0     128       115.0    1
# ...     ...   ...         ...      ...     ...         ...  ...
# 24181  19.0   5.0       138.0      9.0     180         7.0    0
# 24182  19.0   6.0       138.0      9.0     180         6.0    0
# 24183  20.0   1.0       138.0      9.0     180         5.0    0
# 24184  20.0   2.0       138.0      9.0     180         4.0    0
# 24185  20.0   3.0       138.0     10.0     180         3.0    0
#
# [24186 rows x 7 columns]

# %%
final_df['runs_left'] = final_df['target']- final_df['total_runs']
final_df
# Out:
# C:\Users\BABAR\AppData\Local\Temp\ipykernel_6664\1493960828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['runs_left'] = final_df['target']- final_df['total_runs']
#        over  ball  total_runs  wickets  target  balls_left  won  runs_left
# 0       1.0   1.0         0.0      0.0     128       119.0    1      128.0
# 1       1.0   2.0         0.0      0.0     128       118.0    1      128.0
# 2       1.0   3.0         0.0      0.0     128       117.0    1      128.0
# 3       1.0   4.0         2.0      0.0     128       116.0    1      126.0
# 4       1.0   5.0         2.0      0.0     128       115.0    1      126.0
# ...     ...   ...         ...      ...     ...         ...  ...        ...
# 24181  19.0   5.0       138.0      9.0     180         7.0    0       42.0
# 24182  19.0   6.0       138.0      9.0     180         6.0    0       42.0
# 24183  20.0   1.0       138.0      9.0     180         5.0    0       42.0
# 24184  20.0   2.0       138.0      9.0     180         4.0    0       42.0
# 24185  20.0   3.0       138.0     10.0     180         3.0    0       42.0
#
# [24186 rows x 8 columns]

# %%
new_cols =['wickets','balls_left','runs_left','won']
psl_df = final_df[new_cols]
psl_df.isnull().sum()
# Out:
# wickets       2
# balls_left    2
# runs_left     2
# won           0
# dtype: int64

# %%
psl_df = psl_df.apply(pd.to_numeric,errors ='coerce')
psl_df = psl_df.dropna()

# %%
psl_df.isnull().sum()
# Out:
# wickets       0
# balls_left    0
# runs_left     0
# won           0
# dtype: int64

# %%
y = psl_df.iloc[:,3]
x = psl_df.iloc[:,:3]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2,random_state=69)

# %%
SVC_model = SVC()
SVC_model.fit(x_train, y_train)
predicted = SVC_model.predict(x_test)
a = accuracy_score(y_test,predicted)
print('The accuracy using SVC Classifier is:',format(a*100))
# Out:
# The accuracy using SVC Classifier is: 79.65681207359934

# %%
current= {
    "wickets":5,
    "balls_left" :66,
    "runs_left":100,
        }
RF = RandomForestClassifier(n_estimators=100, random_state=42)
RF.fit(x_train, y_train)
current_df = pd.DataFrame(current,index=[0])
RF.predict_proba(current_df)
# Out:
# array([[0.83, 0.17]])

# %%
logistic_model = LogisticRegression()
logistic_model.fit(x_train, y_train)
y_pred_logistic = logistic_model.predict(x_test)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_logistic))
# Out:
# Logistic Regression Accuracy: 0.7947074633037007

# %%
nb_model = GaussianNB()
nb_model.fit(x_train, y_train)
y_pred_nb = nb_model.predict(x_test)
print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
# Out:
# Naive Bayes Accuracy: 0.7113913582799256

# %%
rf_model = RandomForestClassifier()
rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test)
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.7804424229894563

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train, y_train)
y_pred_dt = dt_model.predict(x_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.7626628075253257

# %%
GB = GradientBoostingClassifier()
GB.fit(x_train, y_train)
y_pred_gb = GB.predict(x_test)
print("Gradient Boosting Accuracy:", accuracy_score(y_test, y_pred_gb))
# Out:
# Gradient Boosting Accuracy: 0.8007029150299773

# %%
current= {
    "wickets":7,
    "balls_left" :55,
    "runs_left":88,
        }
GB = GradientBoostingClassifier(n_estimators=100, random_state=42)
GB.fit(x_train, y_train)
current_df = pd.DataFrame(current,index=[0])
# GB.predict_proba(current_df)
probabilities= GB.predict_proba(current_df)
print(f"Win Probability: {probabilities[0][1]:.2f}")
print(f"Lose Probability: {probabilities[0][0]:.2f}")
# Out:
# Win Probability: 0.05
# Lose Probability: 0.95
